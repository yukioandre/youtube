# %% [markdown]
# ## 1. Carregar Informações

# %%
# importa biblioteca
import pandas as pd

# %%
# Carregando os dados
fifa19 = pd.read_csv('fifa19.csv', sep=',', skiprows=None)
fifa19.head()

# Excel:
# x1 = pd.ExcelFile(file) # carrega o arquivo
# df = x1.parse('Sheet1') # carrega a aba

# pd.read_csv("fifa19.csv", dtype={"Potential":"int", "SlidingTackle":"float64"})
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
fifa19.head(10)
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
# 5           5  183277          E. Hazard   27
# 6           6  177003          L. Modrić   32
# 7           7  176580          L. Suárez   31
# 8           8  155862       Sergio Ramos   32
# 9           9  200389           J. Oblak   25
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# 5  https://cdn.sofifa.org/players/4/19/183277.png     Belgium
# ...

# %%
fifa19.tail(3)
# Out:
#        Unnamed: 0      ID            Name  Age  \
# 18204       18204  241638       B. Worman   16
# 18205       18205  246268  D. Walker-Rice   17
# 18206       18206  246269       G. Nugent   16
#
#                                                 Photo Nationality  \
# 18204  https://cdn.sofifa.org/players/4/19/241638.png     England
# 18205  https://cdn.sofifa.org/players/4/19/246268.png     England
# 18206  https://cdn.sofifa.org/players/4/19/246269.png     England
#
#                                       Flag  Overall  Potential  \
# 18204  https://cdn.sofifa.org/flags/14.png       47         67
# 18205  https://cdn.sofifa.org/flags/14.png       47         66
# 18206  https://cdn.sofifa.org/flags/14.png       46         66
#
#                    Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 18204  Cambridge United  ...      41.0    32.0           13.0           11.0
# 18205   Tranmere Rovers  ...      46.0    20.0           25.0           27.0
# ...

# %% [markdown]
# ## 2. Informações sobre o dataset

# %%
fifa19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  object
#  3   Age                       18207 non-null  int64
#  4   Photo                     18207 non-null  object
#  5   Nationality               18207 non-null  object
#  6   Flag                      18207 non-null  object
#  7   Overall                   18207 non-null  int64
#  8   Potential                 18207 non-null  int64
#  9   Club                      17966 non-null  object
#  10  Club Logo                 18207 non-null  object
#  11  Value                     18207 non-null  object
#  12  Wage                      18207 non-null  object
# ...

# %%
fifa19.shape
# Out:
# (18207, 89)

# %%
fifa19.shape[0]
# Out:
# 18207

# %%
fifa19.shape[1]
# Out:
# 89

# %%
print("Temos %0.f linhas e %0.f colunas"%(fifa19.shape[0], fifa19.shape[1]))
# Out:
# Temos 18207 linhas e 89 colunas

# %%
fifa19.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
fifa19.index
# Out:
# RangeIndex(start=0, stop=18207, step=1)

# %% [markdown]
# Se quiser estabelecer uma coluna como índice é só usar set_index, por exemplo:
# - df.set_index('nome da coluna') # para uma coluna
# - df.set_index(['nome da coluna 1', 'nome da coluna 2', ..., 'nome da coluna n'] # para varias colunas
# - df.set_index([pd.index)[1,2,3,4...],'nome do indice') # pra criar um indice novo do zero

# %%
display(fifa19.head())
display(fifa19.tail())
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
pd.set_option('max_colwidth', 40)
pd.set_option('max_rows',20)
pd.set_option('max_columns', 60)

pd.get_option('max_colwidth')
# Out:
# 40

# %%
print(fifa19.head(50))
# Out:
#     Unnamed: 0      ID       Name  Age      Photo Nationality       Flag  \
# 0           0   158023   L. Messi   31  https:...  Argentina   https:...
# 1           1    20801  Cristi...   33  https:...   Portugal   https:...
# 2           2   190871  Neymar Jr   26  https:...     Brazil   https:...
# 3           3   193080     De Gea   27  https:...      Spain   https:...
# 4           4   192985  K. De ...   27  https:...    Belgium   https:...
# ..        ...      ...        ...  ...        ...        ...         ...
# 45         45   195864   P. Pogba   25  https:...     France   https:...
# 46         46   193041   K. Navas   31  https:...  Costa ...   https:...
# 47         47   192505  R. Lukaku   25  https:...    Belgium   https:...
# 48         48   192387  C. Imm...   28  https:...      Italy   https:...
# 49         49   189332  Jordi ...   29  https:...      Spain   https:...
#
#     Overall  Potential       Club  Club Logo    Value   Wage  Special  \
# ...

# %%
def low_values_red(value):
    color = 'red' if value < 92 else 'black'
    return 'color: %s'%color # 'color: red' ou 'color: black'

fifa19[['Overall','Potential']].head(10).style.applymap(low_values_red)
# Out:
# <style  type="text/css" >
#     #T_03e0bf12_fd24_11ea_88c1_1c36bb156c46row0_col0 {
#             color:  black;
#         }    #T_03e0bf12_fd24_11ea_88c1_1c36bb156c46row0_col1 {
#             color:  black;
#         }    #T_03e0bf12_fd24_11ea_88c1_1c36bb156c46row1_col0 {
#             color:  black;
#         }    #T_03e0bf12_fd24_11ea_88c1_1c36bb156c46row1_col1 {
#             color:  black;
#         }    #T_03e0bf12_fd24_11ea_88c1_1c36bb156c46row2_col0 {
#             color:  black;
#         }    #T_03e0bf12_fd24_11ea_88c1_1c36bb156c46row2_col1 {
#             color:  black;
#         }    #T_03e0bf12_fd24_11ea_88c1_1c36bb156c46row3_col0 {
#             color:  red;
#         }    #T_03e0bf12_fd24_11ea_88c1_1c36bb156c46row3_col1 {
#             color:  black;
#         }    #T_03e0bf12_fd24_11ea_88c1_1c36bb156c46row4_col0 {
#             color:  red;
#         }    #T_03e0bf12_fd24_11ea_88c1_1c36bb156c46row4_col1 {
#             color:  black;
# ...

# %%
fifa19.head(10).style.applymap(low_values_red, subset=['Overall', 'Potential'])
# Out:
# <style  type="text/css" >
#     #T_29d2a97e_fd24_11ea_88c1_1c36bb156c46row0_col7 {
#             color:  black;
#         }    #T_29d2a97e_fd24_11ea_88c1_1c36bb156c46row0_col8 {
#             color:  black;
#         }    #T_29d2a97e_fd24_11ea_88c1_1c36bb156c46row1_col7 {
#             color:  black;
#         }    #T_29d2a97e_fd24_11ea_88c1_1c36bb156c46row1_col8 {
#             color:  black;
#         }    #T_29d2a97e_fd24_11ea_88c1_1c36bb156c46row2_col7 {
#             color:  black;
#         }    #T_29d2a97e_fd24_11ea_88c1_1c36bb156c46row2_col8 {
#             color:  black;
#         }    #T_29d2a97e_fd24_11ea_88c1_1c36bb156c46row3_col7 {
#             color:  red;
#         }    #T_29d2a97e_fd24_11ea_88c1_1c36bb156c46row3_col8 {
#             color:  black;
#         }    #T_29d2a97e_fd24_11ea_88c1_1c36bb156c46row4_col7 {
#             color:  red;
#         }    #T_29d2a97e_fd24_11ea_88c1_1c36bb156c46row4_col8 {
#             color:  black;
# ...

# %%
def highlight_max(s):
    is_max = s == s.max() # checa esse booleano s == s.max(), e depois guarda em is_max
    return ['background-color: yellow' if v else '' for v in is_max] 

fifa19.head(10).style.apply(highlight_max, subset=['Age','Overall', 'Potential'])
# Out:
# <style  type="text/css" >
#     #T_99485fce_fd24_11ea_88c1_1c36bb156c46row0_col7 {
#             background-color:  yellow;
#         }    #T_99485fce_fd24_11ea_88c1_1c36bb156c46row0_col8 {
#             background-color:  yellow;
#         }    #T_99485fce_fd24_11ea_88c1_1c36bb156c46row1_col3 {
#             background-color:  yellow;
#         }    #T_99485fce_fd24_11ea_88c1_1c36bb156c46row1_col7 {
#             background-color:  yellow;
#         }    #T_99485fce_fd24_11ea_88c1_1c36bb156c46row1_col8 {
#             background-color:  yellow;
# ...

# %%
fifa19[['Overall','Potential']].head(10).style.\
applymap(low_values_red).\
apply(highlight_max)
# Out:
# <style  type="text/css" >
#     #T_efb8c510_fd24_11ea_88c1_1c36bb156c46row0_col0 {
#             color:  black;
#             background-color:  yellow;
#         }    #T_efb8c510_fd24_11ea_88c1_1c36bb156c46row0_col1 {
#             color:  black;
#             background-color:  yellow;
#         }    #T_efb8c510_fd24_11ea_88c1_1c36bb156c46row1_col0 {
#             color:  black;
#             background-color:  yellow;
#         }    #T_efb8c510_fd24_11ea_88c1_1c36bb156c46row1_col1 {
#             color:  black;
#             background-color:  yellow;
#         }    #T_efb8c510_fd24_11ea_88c1_1c36bb156c46row2_col0 {
#             color:  black;
#             : ;
#         }    #T_efb8c510_fd24_11ea_88c1_1c36bb156c46row2_col1 {
#             color:  black;
#             : ;
#         }    #T_efb8c510_fd24_11ea_88c1_1c36bb156c46row3_col0 {
#             color:  red;
#             : ;
#         }    #T_efb8c510_fd24_11ea_88c1_1c36bb156c46row3_col1 {
#             color:  black;
# ...

# %% [markdown]
# Mais sobre formatação em: https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html

# %% [markdown]
# ## 3. Filtros e Seleções

# %%
fifa19.head(5)
# Out:
#    Unnamed: 0      ID       Name  Age      Photo Nationality       Flag  \
# 0          0   158023   L. Messi   31  https:...  Argentina   https:...
# 1          1    20801  Cristi...   33  https:...   Portugal   https:...
# 2          2   190871  Neymar Jr   26  https:...     Brazil   https:...
# 3          3   193080     De Gea   27  https:...      Spain   https:...
# 4          4   192985  K. De ...   27  https:...    Belgium   https:...
#
#    Overall  Potential       Club  Club Logo    Value   Wage  Special  \
# 0       94         94  FC Bar...  https:...  €110.5M  €565K     2202
# 1       94         94   Juventus  https:...     €77M  €405K     2228
# 2       92         93  Paris ...  https:...  €118.5M  €290K     2143
# 3       91         93  Manche...  https:...     €72M  €260K     1471
# 4       91         92  Manche...  https:...    €102M  €355K     2281
#
#   Preferred Foot  International Reputation  Weak Foot  Skill Moves  Work Rate  \
# ...

# %%
fifa19.loc[1]
# Out:
# Unnamed: 0                1
# ID                    20801
# Name              Cristi...
# Age                      33
# Photo             https:...
#                     ...
# GKHandling               11
# GKKicking                15
# GKPositioning            14
# GKReflexes               11
# Release Clause      €127.1M
# Name: 1, Length: 89, dtype: object

# %%
fifa19.loc[0:5]
# Out:
#    Unnamed: 0      ID       Name  Age      Photo Nationality       Flag  \
# 0          0   158023   L. Messi   31  https:...  Argentina   https:...
# 1          1    20801  Cristi...   33  https:...   Portugal   https:...
# 2          2   190871  Neymar Jr   26  https:...     Brazil   https:...
# 3          3   193080     De Gea   27  https:...      Spain   https:...
# 4          4   192985  K. De ...   27  https:...    Belgium   https:...
# 5          5   183277  E. Hazard   27  https:...    Belgium   https:...
#
#    Overall  Potential       Club  Club Logo    Value   Wage  Special  \
# 0       94         94  FC Bar...  https:...  €110.5M  €565K     2202
# 1       94         94   Juventus  https:...     €77M  €405K     2228
# 2       92         93  Paris ...  https:...  €118.5M  €290K     2143
# 3       91         93  Manche...  https:...     €72M  €260K     1471
# 4       91         92  Manche...  https:...    €102M  €355K     2281
# ...

# %%
fifa19[0:5]
# Out:
#    Unnamed: 0      ID       Name  Age      Photo Nationality       Flag  \
# 0          0   158023   L. Messi   31  https:...  Argentina   https:...
# 1          1    20801  Cristi...   33  https:...   Portugal   https:...
# 2          2   190871  Neymar Jr   26  https:...     Brazil   https:...
# 3          3   193080     De Gea   27  https:...      Spain   https:...
# 4          4   192985  K. De ...   27  https:...    Belgium   https:...
#
#    Overall  Potential       Club  Club Logo    Value   Wage  Special  \
# 0       94         94  FC Bar...  https:...  €110.5M  €565K     2202
# 1       94         94   Juventus  https:...     €77M  €405K     2228
# 2       92         93  Paris ...  https:...  €118.5M  €290K     2143
# 3       91         93  Manche...  https:...     €72M  €260K     1471
# 4       91         92  Manche...  https:...    €102M  €355K     2281
#
#   Preferred Foot  International Reputation  Weak Foot  Skill Moves  Work Rate  \
# ...

# %%
fifa19.loc[0:5, 'Age']
# Out:
# 0    31
# 1    33
# 2    26
# 3    27
# 4    27
# 5    27
# Name: Age, dtype: int64

# %%
fifa19.iloc[0:5, 1:4]
# Out:
#        ID       Name  Age
# 0  158023   L. Messi   31
# 1   20801  Cristi...   33
# 2  190871  Neymar Jr   26
# 3  193080     De Gea   27
# 4  192985  K. De ...   27

# %%
fifa19[0:10]
# Out:
#    Unnamed: 0      ID       Name  Age      Photo Nationality       Flag  \
# 0          0   158023   L. Messi   31  https:...  Argentina   https:...
# 1          1    20801  Cristi...   33  https:...   Portugal   https:...
# 2          2   190871  Neymar Jr   26  https:...     Brazil   https:...
# 3          3   193080     De Gea   27  https:...      Spain   https:...
# 4          4   192985  K. De ...   27  https:...    Belgium   https:...
# 5          5   183277  E. Hazard   27  https:...    Belgium   https:...
# 6          6   177003  L. Modrić   32  https:...    Croatia   https:...
# 7          7   176580  L. Suárez   31  https:...    Uruguay   https:...
# 8          8   155862  Sergio...   32  https:...      Spain   https:...
# 9          9   200389   J. Oblak   25  https:...   Slovenia   https:...
#
#    Overall  Potential       Club  Club Logo    Value   Wage  Special  \
# 0       94         94  FC Bar...  https:...  €110.5M  €565K     2202
# ...

# %%
fifa19.loc[(fifa19['Age'] > 30) & (fifa19['Overall']>=90)]
# Out:
#     Unnamed: 0      ID       Name  Age      Photo Nationality       Flag  \
# 0           0   158023   L. Messi   31  https:...  Argentina   https:...
# 1           1    20801  Cristi...   33  https:...   Portugal   https:...
# 6           6   177003  L. Modrić   32  https:...    Croatia   https:...
# 7           7   176580  L. Suárez   31  https:...    Uruguay   https:...
# 8           8   155862  Sergio...   32  https:...      Spain   https:...
# 12         12   182493   D. Godín   32  https:...    Uruguay   https:...
# 13         13   168542  David ...   32  https:...      Spain   https:...
#
#     Overall  Potential       Club  Club Logo    Value   Wage  Special  \
# 0        94         94  FC Bar...  https:...  €110.5M  €565K     2202
# 1        94         94   Juventus  https:...     €77M  €405K     2228
# 6        91         91  Real M...  https:...     €67M  €420K     2280
# 7        91         91  FC Bar...  https:...     €80M  €455K     2346
# ...

# %%
tiozoes_do_fifa = fifa19.query("Age > 30")
tiozoes_do_fifa.head()
# Out:
#    Unnamed: 0      ID       Name  Age      Photo Nationality       Flag  \
# 0          0   158023   L. Messi   31  https:...  Argentina   https:...
# 1          1    20801  Cristi...   33  https:...   Portugal   https:...
# 6          6   177003  L. Modrić   32  https:...    Croatia   https:...
# 7          7   176580  L. Suárez   31  https:...    Uruguay   https:...
# 8          8   155862  Sergio...   32  https:...      Spain   https:...
#
#    Overall  Potential       Club  Club Logo    Value   Wage  Special  \
# 0       94         94  FC Bar...  https:...  €110.5M  €565K     2202
# 1       94         94   Juventus  https:...     €77M  €405K     2228
# 6       91         91  Real M...  https:...     €67M  €420K     2280
# 7       91         91  FC Bar...  https:...     €80M  €455K     2346
# 8       91         91  Real M...  https:...     €51M  €380K     2201
#
#   Preferred Foot  International Reputation  Weak Foot  Skill Moves  Work Rate  \
# ...

# %%
fifa19[fifa19['Age']>30]
# Out:
#        Unnamed: 0      ID       Name  Age      Photo Nationality       Flag  \
# 0              0   158023   L. Messi   31  https:...  Argentina   https:...
# 1              1    20801  Cristi...   33  https:...   Portugal   https:...
# 6              6   177003  L. Modrić   32  https:...    Croatia   https:...
# 7              7   176580  L. Suárez   31  https:...    Uruguay   https:...
# 8              8   155862  Sergio...   32  https:...      Spain   https:...
# ...          ...      ...        ...  ...        ...        ...         ...
# 17842      17842   182461  Zhou Ting   39  https:...   China PR   https:...
# 17866      17866   232676   N. Hatta   32  https:...      Japan   https:...
# 18043      18043   237917  A. Suzuki   31  https:...      Japan   https:...
# 18171      18171   237746  Y. Uch...   33  https:...      Japan   https:...
# 18183      18183    53748  K. Pil...   44  https:...    England   https:...
#
# ...

# %%
fifa19[fifa19['GKDiving']==fifa19['GKHandling']]
# Out:
#        Unnamed: 0      ID       Name  Age      Photo Nationality       Flag  \
# 2              2   190871  Neymar Jr   26  https:...     Brazil   https:...
# 24            24   138956  G. Chi...   33  https:...      Italy   https:...
# 26            26   209331   M. Salah   26  https:...      Egypt   https:...
# 28            28   198710  J. Rod...   26  https:...   Colombia   https:...
# 36            36   173731    G. Bale   28  https:...      Wales   https:...
# ...          ...      ...        ...  ...        ...        ...         ...
# 18153      18153   246270  M. Dyr...   17  https:...    Denmark   https:...
# 18156      18156   245533  J. Devine   18  https:...    England   https:...
# 18192      18192   245571  S. Squire   18  https:...    England   https:...
# 18194      18194   245862   J. Milli   18  https:...      Italy   https:...
# 18199      18199   244677  M. Bal...   18  https:...     Canada   https:...
#
# ...

# %%
fifa19.filter(['Age', 'ID', 'Name'])
# Out:
#        Age      ID       Name
# 0       31  158023   L. Messi
# 1       33   20801  Cristi...
# 2       26  190871  Neymar Jr
# 3       27  193080     De Gea
# 4       27  192985  K. De ...
# ...    ...     ...        ...
# 18202   19  238813  J. Lun...
# 18203   19  243165  N. Chr...
# 18204   16  241638  B. Worman
# 18205   17  246268  D. Wal...
# 18206   16  246269  G. Nugent
#
# [18207 rows x 3 columns]

# %%
overall_median = fifa19['Overall'].median()
fifa19.query("Overall > @overall_median")
# Out:
#       Unnamed: 0      ID       Name  Age      Photo Nationality       Flag  \
# 0             0   158023   L. Messi   31  https:...  Argentina   https:...
# 1             1    20801  Cristi...   33  https:...   Portugal   https:...
# 2             2   190871  Neymar Jr   26  https:...     Brazil   https:...
# 3             3   193080     De Gea   27  https:...      Spain   https:...
# 4             4   192985  K. De ...   27  https:...    Belgium   https:...
# ...         ...      ...        ...  ...        ...        ...         ...
# 8759       8759   224509   U. Rivas   22  https:...     Mexico   https:...
# 8760       8760   214014  C. Liz...   27  https:...   Colombia   https:...
# 8761       8761   104702  D. Bra...   36  https:...     Norway   https:...
# 8762       8762   229631       Lazo   22  https:...      Spain   https:...
# 8763       8763   246015    L. Mago   23  https:...  Venezuela   https:...
#
# ...

# %%
df_champs = fifa19[fifa19['Nationality'].isin(['Argentina', 'Brazil', 'Germany', 'France','Italy','England'])]
df_champs.head()
# Out:
#     Unnamed: 0      ID       Name  Age  \
# 0            0  158023   L. Messi   31
# 2            2  190871  Neymar Jr   26
# 11          11  182521   T. Kroos   28
# 14          14  215914   N. Kanté   27
# 15          15  211110  P. Dybala   24
#
#                                       Photo Nationality  \
# 0   https://cdn.sofifa.org/players/4/19/...   Argentina
# 2   https://cdn.sofifa.org/players/4/19/...      Brazil
# 11  https://cdn.sofifa.org/players/4/19/...     Germany
# 14  https://cdn.sofifa.org/players/4/19/...      France
# 15  https://cdn.sofifa.org/players/4/19/...   Argentina
#
#                                    Flag  Overall  Potential  \
# 0   https://cdn.sofifa.org/flags/52.png       94         94
# 2   https://cdn.sofifa.org/flags/54.png       92         93
# 11  https://cdn.sofifa.org/flags/21.png       90         90
# 14  https://cdn.sofifa.org/flags/18.png       89         90
# 15  https://cdn.sofifa.org/flags/52.png       89         94
#
# ...

# %%
df_non_champs = fifa19[~fifa19['Nationality'].isin(['Argentina', 'Brazil', 'Germany', 'France','Italy','England'])]
df_non_champs.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 1           1   20801  Cristiano Ronaldo   33
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
# 5           5  183277          E. Hazard   27
# 6           6  177003          L. Modrić   32
#
#                                      Photo Nationality  \
# 1  https://cdn.sofifa.org/players/4/19/...    Portugal
# 3  https://cdn.sofifa.org/players/4/19/...       Spain
# 4  https://cdn.sofifa.org/players/4/19/...     Belgium
# 5  https://cdn.sofifa.org/players/4/19/...     Belgium
# 6  https://cdn.sofifa.org/players/4/19/...     Croatia
#
#                                   Flag  Overall  Potential               Club  \
# 1  https://cdn.sofifa.org/flags/38.png       94         94           Juventus
# 3  https://cdn.sofifa.org/flags/45.png       91         93  Manchester United
# 4   https://cdn.sofifa.org/flags/7.png       91         92    Manchester City
# ...

# %%
numerics = ['int16', 'int32', 'int64', 'float16','float32','float64']
fifa19_numerics = fifa19.select_dtypes(include= numerics)
fifa19_numerics.head()
# Out:
#    Unnamed: 0      ID  Age  Overall  Potential  Special  \
# 0           0  158023   31       94         94     2202
# 1           1   20801   33       94         94     2228
# 2           2  190871   26       92         93     2143
# 3           3  193080   27       91         93     1471
# 4           4  192985   27       91         92     2281
#
#    International Reputation  Weak Foot  Skill Moves  Jersey Number  Crossing  \
# 0                       5.0        4.0          4.0           10.0      84.0
# 1                       5.0        4.0          5.0            7.0      84.0
# 2                       5.0        5.0          5.0           10.0      79.0
# 3                       4.0        3.0          1.0            1.0      17.0
# 4                       4.0        5.0          4.0            7.0      93.0
#
#    Finishing  HeadingAccuracy  ShortPassing  Volleys  Dribbling  Curve  \
# 0       95.0             70.0          90.0     86.0       97.0   93.0
# ...

# %%
numerics = ['int16', 'int32', 'int64', 'float16','float32','float64']
fifa19_non_numerics = fifa19.select_dtypes(exclude= numerics)
fifa19_non_numerics.head()
# Out:
#                 Name                                    Photo Nationality  \
# 0           L. Messi  https://cdn.sofifa.org/players/4/19/...   Argentina
# 1  Cristiano Ronaldo  https://cdn.sofifa.org/players/4/19/...    Portugal
# 2          Neymar Jr  https://cdn.sofifa.org/players/4/19/...      Brazil
# 3             De Gea  https://cdn.sofifa.org/players/4/19/...       Spain
# 4       K. De Bruyne  https://cdn.sofifa.org/players/4/19/...     Belgium
#
#                                   Flag                 Club  \
# 0  https://cdn.sofifa.org/flags/52.png         FC Barcelona
# 1  https://cdn.sofifa.org/flags/38.png             Juventus
# 2  https://cdn.sofifa.org/flags/54.png  Paris Saint-Germain
# 3  https://cdn.sofifa.org/flags/45.png    Manchester United
# 4   https://cdn.sofifa.org/flags/7.png      Manchester City
#
#                                  Club Logo    Value   Wage Preferred Foot  \
# 0  https://cdn.sofifa.org/teams/2/light...  €110.5M  €565K           Left
# ...

# %%
fifa19.sort_values(by='Overall', ascending=False).head(10)
# Out:
#     Unnamed: 0      ID               Name  Age  \
# 0            0  158023           L. Messi   31
# 1            1   20801  Cristiano Ronaldo   33
# 2            2  190871          Neymar Jr   26
# 3            3  193080             De Gea   27
# 4            4  192985       K. De Bruyne   27
# 5            5  183277          E. Hazard   27
# 6            6  177003          L. Modrić   32
# 7            7  176580          L. Suárez   31
# 8            8  155862       Sergio Ramos   32
# 12          12  182493           D. Godín   32
#
#                                       Photo Nationality  \
# 0   https://cdn.sofifa.org/players/4/19/...   Argentina
# 1   https://cdn.sofifa.org/players/4/19/...    Portugal
# 2   https://cdn.sofifa.org/players/4/19/...      Brazil
# 3   https://cdn.sofifa.org/players/4/19/...       Spain
# 4   https://cdn.sofifa.org/players/4/19/...     Belgium
# 5   https://cdn.sofifa.org/players/4/19/...     Belgium
# ...

# %%
fifa19.drop_duplicates()
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                          Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/...   Argentina
# 1      https://cdn.sofifa.org/players/4/19/...    Portugal
# 2      https://cdn.sofifa.org/players/4/19/...      Brazil
# 3      https://cdn.sofifa.org/players/4/19/...       Spain
# ...

# %% [markdown]
# ## 4. Estatística Descritiva

# %%
fifa19.describe()
# Out:
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  18207.000000   18207.000000  18207.000000  18207.000000  18207.000000
# mean    9103.000000  214298.338606     25.122206     66.238699     71.307299
# std     5256.052511   29965.244204      4.669943      6.908930      6.136496
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     4551.500000  200315.500000     21.000000     62.000000     67.000000
# 50%     9103.000000  221759.000000     25.000000     66.000000     71.000000
# 75%    13654.500000  236529.500000     28.000000     71.000000     75.000000
# max    18206.000000  246620.000000     45.000000     94.000000     95.000000
#
#             Special  International Reputation     Weak Foot   Skill Moves  \
# count  18207.000000              18159.000000  18159.000000  18159.000000
# mean    1597.809908                  1.113222      2.947299      2.361308
# ...

# %%
fifa19['Age'].describe(percentiles=[0.1, 0.2, 0.8, 0.99])
# Out:
# count    18207.000000
# mean        25.122206
# std          4.669943
# min         16.000000
# 10%         19.000000
# 20%         21.000000
# 50%         25.000000
# 80%         29.000000
# 99%         36.000000
# max         45.000000
# Name: Age, dtype: float64

# %%
fifa19.agg({'Age':['min','max','skew','median'],
           'Overall':['mean','min']})
# Out:
#               Age    Overall
# max     45.000000        NaN
# mean          NaN  66.238699
# median  25.000000        NaN
# min     16.000000  46.000000
# skew     0.391764        NaN

# %%
df_champs.groupby('Nationality')['Age','Overall'].mean().sort_values(by='Overall', ascending=False)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                    Age    Overall
# Nationality
# Brazil       27.625151  71.251511
# Argentina    26.205977  68.572038
# Italy        25.928775  68.158120
# France       24.615974  67.798687
# Germany      24.338063  66.086811
# England      24.030084  63.429603

# %%
import numpy as np
pd.pivot_table(df_champs, index='Nationality', aggfunc=np.mean)
# Out:
#              Acceleration        Age  Aggression    Agility    Balance  \
# Nationality
# Argentina       64.625000  26.205977   56.725427  64.193376  64.376068
# Brazil          66.318788  27.625151   59.972121  65.201212  63.966061
# England         64.945081  24.030084   54.275196  63.372963  64.732649
# France          64.524698  24.615974   56.958288  62.819978  63.919868
# Germany         63.287029  24.338063   55.931381  62.354812  61.830126
# Italy           63.167382  25.928775   55.429185  63.065808  62.858369
#
#              BallControl  Composure   Crossing      Curve  Dribbling  \
# Nationality
# Argentina      60.808761  60.452991  51.319444  48.883547  58.068376
# Brazil         63.841212  65.241212  54.699394  53.403636  60.850909
# England        56.073024  56.153893  47.249849  44.498491  53.234762
# France         59.787047  60.586169  51.739846  47.963776  56.736553
# Germany        56.675314  56.370711  48.337238  45.133054  53.167364
# ...

# %%
pd.pivot_table(df_champs, index=['Nationality'], values=['Age','Overall','Strength'], aggfunc=np.mean)
# Out:
#                    Age    Overall   Strength
# Nationality
# Argentina    26.205977  68.572038  65.561966
# Brazil       27.625151  71.251511  67.263030
# England      24.030084  63.429603  64.068799
# France       24.615974  67.798687  66.480790
# Germany      24.338063  66.086811  66.953975
# Italy        25.928775  68.158120  65.114449

# %%
pd.pivot_table(df_champs, index=['Nationality','Position'], columns=['Club'],values=['Age','Overall','Strength'], aggfunc=np.mean)
# Out:
#                                       Age                        \
# Club                  SSV Jahn Regensburg 1. FC Heidenheim 1846
# Nationality Position
# Argentina   CAM                       NaN                   NaN
#             CB                        NaN                   NaN
#             CDM                       NaN                   NaN
#             CF                        NaN                   NaN
#             CM                        NaN                   NaN
# ...                                   ...                   ...
# Italy       RM                        NaN                   NaN
#             RS                        NaN                   NaN
#             RW                        NaN                   NaN
#             RWB                       NaN                   NaN
#             ST                        NaN                   NaN
#
#                                                                       \
# ...

# %%
df_champs.Nationality.value_counts()
# Out:
# England      1662
# Germany      1198
# Argentina     937
# France        914
# Brazil        827
# Italy         702
# Name: Nationality, dtype: int64

# %%
df_champs.Nationality.value_counts(normalize=True)
# Out:
# England      0.266346
# Germany      0.191987
# Argentina    0.150160
# France       0.146474
# Brazil       0.132532
# Italy        0.112500
# Name: Nationality, dtype: float64

# %%
df_champs.groupby('Nationality')['Position'].value_counts()
# Out:
# Nationality  Position
# Argentina    ST          125
#              CB           99
#              GK           97
#              LM           64
#              RM           62
#                         ...
# Italy        RDM           4
#              RWB           2
#              LDM           1
#              LWB           1
#              RF            1
# Name: Position, Length: 145, dtype: int64

# %% [markdown]
# ## SQL no Pandas

# %%
# off-topic: como melhorar o desempenho
# pip install modin
import modin.pandas as pd

# %%
import pandasql as ps

# %%
query = """ 
select ID, Age, Name from fifa19 where Age > 33
"""

# %%
ps.sqldf(query, locals())
# Out:
#          ID  Age            Name
# 0      1179   40       G. Buffon
# 1        41   34         Iniesta
# 2    171919   35           Naldo
# 3    120533   35            Pepe
# 4     41236   36  Z. Ibrahimović
# ..      ...  ...             ...
# 888  244440   36     F. Nicastro
# 889   51963   44       T. Warner
# 890  100899   40     S. Phillips
# 891  182461   39       Zhou Ting
# 892   53748   44   K. Pilkington
#
# [893 rows x 3 columns]
