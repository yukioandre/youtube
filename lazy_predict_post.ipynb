# %%
# carrega as bibliotecas para tratar os dados
import pandas as pd
import numpy as np

# bibliotecas para modelos
from sklearn.model_selection import train_test_split
import lazypredict
from lazypredict.Supervised import LazyClassifier
# Out:
# /Users/andremota/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
# carrega os dados
df = pd.read_csv("german_credit_data.csv")
df.head()
# Out:
#    Unnamed: 0  Age     Sex  Job Housing Saving accounts Checking account  \
# 0           0   67    male    2     own             NaN           little
# 1           1   22  female    2     own          little         moderate
# 2           2   49    male    1     own          little              NaN
# 3           3   45    male    2    free          little           little
# 4           4   53    male    2    free          little           little
#
#    Credit amount  Duration              Purpose  Risk
# 0           1169         6             radio/TV  good
# 1           5951        48             radio/TV   bad
# 2           2096        12            education  good
# 3           7882        42  furniture/equipment  good
# 4           4870        24                  car   bad

# %%
df['Risk'] = np.where(df['Risk']=='bad', 1, 0)

# %%
df.head()
# Out:
#    Unnamed: 0  Age     Sex  Job Housing Saving accounts Checking account  \
# 0           0   67    male    2     own             NaN           little
# 1           1   22  female    2     own          little         moderate
# 2           2   49    male    1     own          little              NaN
# 3           3   45    male    2    free          little           little
# 4           4   53    male    2    free          little           little
#
#    Credit amount  Duration              Purpose  Risk
# 0           1169         6             radio/TV     0
# 1           5951        48             radio/TV     1
# 2           2096        12            education     0
# 3           7882        42  furniture/equipment     0
# 4           4870        24                  car     1

# %%
# seleciona as features e variavel target
X = df[['Age', 'Credit amount', 'Duration']]
y = df['Risk']

# divide em treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=999)

# %%
X_train.head()
# Out:
#      Age  Credit amount  Duration
# 763   30          12680        21
# 534   25           3105        24
# 86    27           1295        18
# 927   39          10297        48
# 134   21          10144        60

# %%
clf = LazyClassifier(verbose=0, ignore_warnings=True)
models, predictions = clf.fit(X_train, X_test, y_train, y_test)
models
# Out:
# 100%|██████████| 29/29 [00:02<00:00, 11.07it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LabelPropagation                   0.65               0.55     0.55      0.62
# NearestCentroid                    0.59               0.55     0.55      0.59
# GaussianNB                         0.66               0.55     0.55      0.61
# LabelSpreading                     0.65               0.55     0.55      0.61
# BaggingClassifier                  0.65               0.55     0.55      0.61
# Perceptron                         0.64               0.55     0.55      0.61
# ExtraTreeClassifier                0.62               0.55     0.55      0.61
# NuSVC                              0.67               0.54     0.54      0.60
# SVC                                0.67               0.54     0.54      0.61
# QuadraticDiscriminantAnalysis      0.65               0.54     0.54      0.61
# KNeighborsClassifier               0.64               0.54     0.54      0.61
# RandomForestClassifier             0.63               0.54     0.54      0.61
# ExtraTreesClassifier               0.63               0.54     0.54      0.60
# LGBMClassifier                     0.62               0.54     0.54      0.60
# XGBClassifier                      0.61               0.53     0.53      0.59
# DecisionTreeClassifier             0.60               0.53     0.53      0.59
# LinearDiscriminantAnalysis         0.66               0.52     0.52      0.58
# CalibratedClassifierCV             0.66               0.52     0.52      0.57
# RidgeClassifierCV                  0.65               0.51     0.51      0.57
# RidgeClassifier                    0.65               0.51     0.51      0.57
# LinearSVC                          0.65               0.51     0.51      0.57
# LogisticRegression                 0.65               0.51     0.51      0.57
# BernoulliNB                        0.62               0.51     0.51      0.58
# SGDClassifier                      0.66               0.50     0.50      0.53
# PassiveAggressiveClassifier        0.65               0.49     0.49      0.53
# AdaBoostClassifier                 0.61               0.48     0.48      0.54
# DummyClassifier                    0.54               0.47     0.47      0.53
#
#                                Time Taken
# Model
# LabelPropagation                     0.08
# NearestCentroid                      0.04
# GaussianNB                           0.03
# LabelSpreading                       0.09
# BaggingClassifier                    0.10
# Perceptron                           0.03
# ExtraTreeClassifier                  0.03
# NuSVC                                0.06
# SVC                                  0.05
# QuadraticDiscriminantAnalysis        0.04
# KNeighborsClassifier                 0.06
# RandomForestClassifier               0.35
# ExtraTreesClassifier                 0.33
# LGBMClassifier                       0.23
# XGBClassifier                        0.16
# DecisionTreeClassifier               0.04
# LinearDiscriminantAnalysis           0.03
# CalibratedClassifierCV               0.15
# RidgeClassifierCV                    0.03
# RidgeClassifier                      0.05
# LinearSVC                            0.07
# LogisticRegression                   0.03
# BernoulliNB                          0.03
# SGDClassifier                        0.03
# PassiveAggressiveClassifier          0.02
# AdaBoostClassifier                   0.41
# DummyClassifier                      0.03
