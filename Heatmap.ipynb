# %%
import pandas as pd

# %%
df = pd.read_csv('melb_data.csv')
df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# 0        NaN        Yarra  -37.7996    144.9984  Northern Metropolitan
# 1     1900.0        Yarra  -37.8079    144.9934  Northern Metropolitan
# 2     1900.0        Yarra  -37.8093    144.9944  Northern Metropolitan
# 3        NaN        Yarra  -37.7969    144.9969  Northern Metropolitan
# 4     2014.0        Yarra  -37.8072    144.9941  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# 3        4019.0
# 4        4019.0
#
# [5 rows x 21 columns]

# %%
df_2 = df.select_dtypes(exclude='object')

# %%
df_2.head()
# Out:
#    Rooms      Price  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 0      2  1480000.0       2.5    3067.0       2.0       1.0  1.0     202.0
# 1      2  1035000.0       2.5    3067.0       2.0       1.0  0.0     156.0
# 2      3  1465000.0       2.5    3067.0       3.0       2.0  0.0     134.0
# 3      3   850000.0       2.5    3067.0       3.0       2.0  1.0      94.0
# 4      4  1600000.0       2.5    3067.0       3.0       1.0  2.0     120.0
#
#    BuildingArea  YearBuilt  Lattitude  Longtitude  Propertycount
# 0           NaN        NaN   -37.7996    144.9984         4019.0
# 1          79.0     1900.0   -37.8079    144.9934         4019.0
# 2         150.0     1900.0   -37.8093    144.9944         4019.0
# 3           NaN        NaN   -37.7969    144.9969         4019.0
# 4         142.0     2014.0   -37.8072    144.9941         4019.0

# %%
df_2.corr()
# Out:
#                   Rooms     Price  Distance  Postcode  Bedroom2  Bathroom  \
# Rooms          1.000000  0.496634  0.294203  0.055303  0.944190  0.592934
# Price          0.496634  1.000000 -0.162522  0.107867  0.475951  0.467038
# Distance       0.294203 -0.162522  1.000000  0.431514  0.295927  0.127155
# Postcode       0.055303  0.107867  0.431514  1.000000  0.060584  0.113664
# Bedroom2       0.944190  0.475951  0.295927  0.060584  1.000000  0.584685
# Bathroom       0.592934  0.467038  0.127155  0.113664  0.584685  1.000000
# Car            0.408483  0.238979  0.262994  0.050289  0.405325  0.322246
# Landsize       0.025678  0.037507  0.025004  0.024558  0.025646  0.037130
# BuildingArea   0.124127  0.090981  0.099481  0.055475  0.122319  0.111933
# YearBuilt     -0.065413 -0.323617  0.246379  0.032863 -0.053319  0.152702
# Lattitude      0.015948 -0.212934 -0.130723 -0.406104  0.015925 -0.070594
# Longtitude     0.100771  0.203656  0.239425  0.445357  0.102238  0.118971
# Propertycount -0.081530 -0.042153 -0.054910  0.062304 -0.081350 -0.052201
#
#                     Car  Landsize  BuildingArea  YearBuilt  Lattitude  \
# Rooms          0.408483  0.025678      0.124127  -0.065413   0.015948
# Price          0.238979  0.037507      0.090981  -0.323617  -0.212934
# Distance       0.262994  0.025004      0.099481   0.246379  -0.130723
# Postcode       0.050289  0.024558      0.055475   0.032863  -0.406104
# Bedroom2       0.405325  0.025646      0.122319  -0.053319   0.015925
# Bathroom       0.322246  0.037130      0.111933   0.152702  -0.070594
# Car            1.000000  0.026770      0.096101   0.104515  -0.001963
# Landsize       0.026770  1.000000      0.500485   0.036451   0.009695
# BuildingArea   0.096101  0.500485      1.000000   0.019665   0.043420
# YearBuilt      0.104515  0.036451      0.019665   1.000000   0.060445
# Lattitude     -0.001963  0.009695      0.043420   0.060445   1.000000
# Longtitude     0.063395  0.010833     -0.023810  -0.003470  -0.357634
# Propertycount -0.024295 -0.006854     -0.028840   0.006361   0.047086
#
#                Longtitude  Propertycount
# Rooms            0.100771      -0.081530
# Price            0.203656      -0.042153
# Distance         0.239425      -0.054910
# Postcode         0.445357       0.062304
# Bedroom2         0.102238      -0.081350
# Bathroom         0.118971      -0.052201
# Car              0.063395      -0.024295
# Landsize         0.010833      -0.006854
# BuildingArea    -0.023810      -0.028840
# YearBuilt       -0.003470       0.006361
# Lattitude       -0.357634       0.047086
# Longtitude       1.000000       0.065988
# Propertycount    0.065988       1.000000

# %%
# Utilizando o próprio Pandas
df_2.corr().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_dc7f2_row0_col0, #T_dc7f2_row1_col1, #T_dc7f2_row2_col2, #T_dc7f2_row3_col3, #T_dc7f2_row4_col4, #T_dc7f2_row5_col5, #T_dc7f2_row6_col6, #T_dc7f2_row7_col7, #T_dc7f2_row8_col8, #T_dc7f2_row9_col9, #T_dc7f2_row10_col10, #T_dc7f2_row11_col11, #T_dc7f2_row12_col12 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_dc7f2_row0_col1, #T_dc7f2_row0_col5 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_dc7f2_row0_col2, #T_dc7f2_row4_col2 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_dc7f2_row0_col3, #T_dc7f2_row4_col3, #T_dc7f2_row8_col3, #T_dc7f2_row9_col10 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_dc7f2_row0_col4, #T_dc7f2_row4_col0 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_dc7f2_row0_col6, #T_dc7f2_row6_col1 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_dc7f2_row0_col7, #T_dc7f2_row2_col7, #T_dc7f2_row4_col7, #T_dc7f2_row6_col7, #T_dc7f2_row11_col10 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_dc7f2_row0_col8 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_dc7f2_row0_col9 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_dc7f2_row0_col10, #T_dc7f2_row4_col10 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_dc7f2_row0_col11, #T_dc7f2_row4_col11, #T_dc7f2_row5_col6 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_dc7f2_row0_col12, #T_dc7f2_row1_col2, #T_dc7f2_row1_col9, #T_dc7f2_row3_col10, #T_dc7f2_row4_col12, #T_dc7f2_row9_col1, #T_dc7f2_row10_col3, #T_dc7f2_row10_col5, #T_dc7f2_row10_col11, #T_dc7f2_row12_col0, #T_dc7f2_row12_col4, #T_dc7f2_row12_col6, #T_dc7f2_row12_col7, #T_dc7f2_row12_col8 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_dc7f2_row1_col0 {
#   background-color: #60a7d2;
#   color: #f1f1f1;
# }
# #T_dc7f2_row1_col3, #T_dc7f2_row6_col2, #T_dc7f2_row6_col5 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_dc7f2_row1_col4, #T_dc7f2_row7_col8 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_dc7f2_row1_col5, #T_dc7f2_row8_col7 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_dc7f2_row1_col6 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_dc7f2_row1_col7, #T_dc7f2_row5_col7, #T_dc7f2_row7_col6, #T_dc7f2_row8_col12, #T_dc7f2_row9_col7, #T_dc7f2_row9_col8 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_dc7f2_row1_col8 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_dc7f2_row1_col10, #T_dc7f2_row5_col8 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_dc7f2_row1_col11 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_dc7f2_row1_col12 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_dc7f2_row2_col0, #T_dc7f2_row11_col2 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_dc7f2_row2_col1, #T_dc7f2_row2_col8, #T_dc7f2_row6_col8 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_dc7f2_row2_col3, #T_dc7f2_row5_col1 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_dc7f2_row2_col4, #T_dc7f2_row5_col11 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_dc7f2_row2_col5 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_dc7f2_row2_col6 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_dc7f2_row2_col9 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_dc7f2_row2_col10 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_dc7f2_row2_col11 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_dc7f2_row2_col12, #T_dc7f2_row5_col12, #T_dc7f2_row9_col4 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_dc7f2_row3_col0, #T_dc7f2_row9_col6 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_dc7f2_row3_col1, #T_dc7f2_row6_col3 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_dc7f2_row3_col2 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_dc7f2_row3_col4 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_dc7f2_row3_col5 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_dc7f2_row3_col6 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_dc7f2_row3_col7, #T_dc7f2_row10_col2 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_dc7f2_row3_col8, #T_dc7f2_row9_col12 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_dc7f2_row3_col9 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_dc7f2_row3_col11 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_dc7f2_row3_col12, #T_dc7f2_row11_col12 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_dc7f2_row4_col1 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_dc7f2_row4_col5 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_dc7f2_row4_col6 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_dc7f2_row4_col8 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_dc7f2_row4_col9 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_dc7f2_row5_col0 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_dc7f2_row5_col2, #T_dc7f2_row12_col9 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_dc7f2_row5_col3 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_dc7f2_row5_col4 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_dc7f2_row5_col9 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_dc7f2_row5_col10, #T_dc7f2_row11_col9 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_dc7f2_row6_col0, #T_dc7f2_row6_col4 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_dc7f2_row6_col9, #T_dc7f2_row12_col10 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_dc7f2_row6_col10 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_dc7f2_row6_col11, #T_dc7f2_row9_col3, #T_dc7f2_row12_col11 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_dc7f2_row6_col12 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_dc7f2_row7_col0, #T_dc7f2_row7_col4, #T_dc7f2_row7_col5 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_dc7f2_row7_col1, #T_dc7f2_row7_col9, #T_dc7f2_row7_col11 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_dc7f2_row7_col2 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_dc7f2_row7_col3 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_dc7f2_row7_col10 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_dc7f2_row7_col12, #T_dc7f2_row10_col8 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_dc7f2_row8_col0, #T_dc7f2_row8_col4 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_dc7f2_row8_col1 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_dc7f2_row8_col2 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_dc7f2_row8_col5, #T_dc7f2_row11_col0, #T_dc7f2_row11_col4 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_dc7f2_row8_col6, #T_dc7f2_row10_col12 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_dc7f2_row8_col9, #T_dc7f2_row9_col11 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_dc7f2_row8_col10 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_dc7f2_row8_col11 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_dc7f2_row9_col0 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_dc7f2_row9_col2 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_dc7f2_row9_col5 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_dc7f2_row10_col0, #T_dc7f2_row10_col4, #T_dc7f2_row12_col2 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_dc7f2_row10_col1, #T_dc7f2_row11_col6 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_dc7f2_row10_col6 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_dc7f2_row10_col7, #T_dc7f2_row11_col7, #T_dc7f2_row12_col5 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_dc7f2_row10_col9 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_dc7f2_row11_col1 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_dc7f2_row11_col3 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_dc7f2_row11_col5 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_dc7f2_row11_col8 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_dc7f2_row12_col1 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_dc7f2_row12_col3 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# </style>
# <table id="T_dc7f2_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Rooms</th>
#       <th class="col

# %%
import seaborn as sns

# %%
sns.heatmap(df_2.corr())
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(12, 8))

_ = sns.heatmap(df_2.corr(), cmap = 'Blues', linewidth = 0.5, annot = True)
