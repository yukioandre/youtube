# %%
import pandas as pd

# %%
fifa19 = pd.read_csv('fifa19.csv')
fifa19.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
# loc: passa o indice das linhas
fifa19.loc[0:5]
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
# 5           5  183277          E. Hazard   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# 5  https://cdn.sofifa.org/players/4/19/183277.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# ...

# %%
# indice das linhas e nome da coluna
fifa19.loc[0:10, 'Name']
# Out:
# 0              L. Messi
# 1     Cristiano Ronaldo
# 2             Neymar Jr
# 3                De Gea
# 4          K. De Bruyne
# 5             E. Hazard
# 6             L. Modrić
# 7             L. Suárez
# 8          Sergio Ramos
# 9              J. Oblak
# 10       R. Lewandowski
# Name: Name, dtype: object

# %%
# iloc: numero das linhas E colunas
fifa19_filtro_iloc = fifa19.iloc[0:10, 0:3]
fifa19_filtro_iloc.tail()
# Out:
#    Unnamed: 0      ID          Name
# 5           5  183277     E. Hazard
# 6           6  177003     L. Modrić
# 7           7  176580     L. Suárez
# 8           8  155862  Sergio Ramos
# 9           9  200389      J. Oblak

# %%
fifa19.iloc[0:5, :]
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
fifa19.loc[(fifa19['Age']>30) |  (fifa19['Overall']>90)] # e: &,  ou: |
# Out:
#        Unnamed: 0      ID               Name  Age  \
# 0               0  158023           L. Messi   31
# 1               1   20801  Cristiano Ronaldo   33
# 2               2  190871          Neymar Jr   26
# 3               3  193080             De Gea   27
# 4               4  192985       K. De Bruyne   27
# ...           ...     ...                ...  ...
# 17842       17842  182461          Zhou Ting   39
# 17866       17866  232676           N. Hatta   32
# 18043       18043  237917          A. Suzuki   31
# 18171       18171  237746        Y. Uchimura   33
# 18183       18183   53748      K. Pilkington   44
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
fifa19.query("Age > 30")
# Out:
#        Unnamed: 0      ID               Name  Age  \
# 0               0  158023           L. Messi   31
# 1               1   20801  Cristiano Ronaldo   33
# 6               6  177003          L. Modrić   32
# 7               7  176580          L. Suárez   31
# 8               8  155862       Sergio Ramos   32
# ...           ...     ...                ...  ...
# 17842       17842  182461          Zhou Ting   39
# 17866       17866  232676           N. Hatta   32
# 18043       18043  237917          A. Suzuki   31
# 18171       18171  237746        Y. Uchimura   33
# 18183       18183   53748      K. Pilkington   44
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 6      https://cdn.sofifa.org/players/4/19/177003.png     Croatia
# 7      https://cdn.sofifa.org/players/4/19/176580.png     Uruguay
# ...

# %%
fifa19.query("Age > 30 & Overall > 90")
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 6           6  177003          L. Modrić   32
# 7           7  176580          L. Suárez   31
# 8           8  155862       Sergio Ramos   32
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 6  https://cdn.sofifa.org/players/4/19/177003.png     Croatia
# 7  https://cdn.sofifa.org/players/4/19/176580.png     Uruguay
# 8  https://cdn.sofifa.org/players/4/19/155862.png       Spain
#
#                                   Flag  Overall  Potential          Club  ...  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94  FC Barcelona  ...
# 1  https://cdn.sofifa.org/flags/38.png       94         94      Juventus  ...
# ...

# %%
Overall_mediana = fifa19['Overall'].median()
fifa19.query("Overall > @Overall_mediana")
# Out:
#       Unnamed: 0      ID               Name  Age  \
# 0              0  158023           L. Messi   31
# 1              1   20801  Cristiano Ronaldo   33
# 2              2  190871          Neymar Jr   26
# 3              3  193080             De Gea   27
# 4              4  192985       K. De Bruyne   27
# ...          ...     ...                ...  ...
# 8759        8759  224509           U. Rivas   22
# 8760        8760  214014        C. Lizarazo   27
# 8761        8761  104702         D. Braaten   36
# 8762        8762  229631               Lazo   22
# 8763        8763  246015            L. Mago   23
#
#                                                Photo Nationality  \
# 0     https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1      https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2     https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3     https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
fifa19.query("Nationality == 'Brazil'")
# Out:
#        Unnamed: 0      ID              Name  Age  \
# 2               2  190871         Neymar Jr   26
# 27             27  200145          Casemiro   26
# 32             32  189242          Coutinho   26
# 35             35  176676           Marcelo   30
# 39             39  164240      Thiago Silva   33
# ...           ...     ...               ...  ...
# 17059       17059  243750  Gianluca Zanette   21
# 17446       17446  235949         Strefezza   21
# 17588       17588  244311     Lucas Ribeiro   19
# 17611       17611  241268   Felipe Ferreyra   20
# 18170       18170  246447   Nicolas Firmino   17
#
#                                                 Photo Nationality  \
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 27     https://cdn.sofifa.org/players/4/19/200145.png      Brazil
# 32     https://cdn.sofifa.org/players/4/19/189242.png      Brazil
# 35     https://cdn.sofifa.org/players/4/19/176676.png      Brazil
# ...

# %%
fifa19[fifa19['Age'] != 30] # >, <, <=, >=, !=, ==
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
fifa19_v2 = fifa19.filter(['ID','Age', 'Name', 'Overall', 'Nationality', 'Club'])
fifa19_v2.head()
# Out:
#        ID  Age               Name  Overall Nationality                 Club
# 0  158023   31           L. Messi       94   Argentina         FC Barcelona
# 1   20801   33  Cristiano Ronaldo       94    Portugal             Juventus
# 2  190871   26          Neymar Jr       92      Brazil  Paris Saint-Germain
# 3  193080   27             De Gea       91       Spain    Manchester United
# 4  192985   27       K. De Bruyne       91     Belgium      Manchester City

# %%
fifa19[fifa19['Nationality'].isin(['Brazil','Chile', 'Colombia', 'Peru'])]
# Out:
#        Unnamed: 0      ID             Name  Age  \
# 2               2  190871        Neymar Jr   26
# 27             27  200145         Casemiro   26
# 28             28  198710     J. Rodríguez   26
# 32             32  189242         Coutinho   26
# 35             35  176676          Marcelo   30
# ...           ...     ...              ...  ...
# 18110       18110  243434         G. Tegue   18
# 18152       18152  245755         J. Yabur   19
# 18170       18170  246447  Nicolas Firmino   17
# 18182       18182  246001          Y. Góez   18
# 18193       18193  244823       N. Fuentes   18
#
#                                                 Photo Nationality  \
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 27     https://cdn.sofifa.org/players/4/19/200145.png      Brazil
# 28     https://cdn.sofifa.org/players/4/19/198710.png    Colombia
# 32     https://cdn.sofifa.org/players/4/19/189242.png      Brazil
# ...
