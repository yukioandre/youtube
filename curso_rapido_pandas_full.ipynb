# %%
# importa biblioteca
import pandas as pd

# %%
df = pd.read_csv("fifa19.csv", sep = ',', decimal=',', skiprows=None)
df.head()

# x1 = pd.ExcelFile(file) # carregar arquivo
# df = x1.parse('Sheet1') # carrega sheet
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
df.tail()
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 18202  https://cdn.sofifa.org/players/4/19/238813.png     England
# 18203  https://cdn.sofifa.org/players/4/19/243165.png      Sweden
# 18204  https://cdn.sofifa.org/players/4/19/241638.png     England
# 18205  https://cdn.sofifa.org/players/4/19/246268.png     England
# 18206  https://cdn.sofifa.org/players/4/19/246269.png     England
#
#                                       Flag  Overall  Potential  \
# 18202  https://cdn.sofifa.org/flags/14.png       47         65
# 18203  https://cdn.sofifa.org/flags/46.png       47         63
# 18204  https://cdn.sofifa.org/flags/14.png       47         67
# ...

# %%
df.head(10)
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
# 5           5  183277          E. Hazard   27
# 6           6  177003          L. Modrić   32
# 7           7  176580          L. Suárez   31
# 8           8  155862       Sergio Ramos   32
# 9           9  200389           J. Oblak   25
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# 5  https://cdn.sofifa.org/players/4/19/183277.png     Belgium
# ...

# %%
# memoria, tipo do campo, entradas nao-nulas, etc
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  object
#  3   Age                       18207 non-null  int64
#  4   Photo                     18207 non-null  object
#  5   Nationality               18207 non-null  object
#  6   Flag                      18207 non-null  object
#  7   Overall                   18207 non-null  int64
#  8   Potential                 18207 non-null  int64
#  9   Club                      17966 non-null  object
#  10  Club Logo                 18207 non-null  object
#  11  Value                     18207 non-null  object
#  12  Wage                      18207 non-null  object
# ...

# %%
# numero de linhas e colunas
df.shape
# Out:
# (18207, 89)

# %%
print("Temos %0.f linhas e %0.f colunas"%(df.shape[0], df.shape[1])) #poderia ser 0.2
# Out:
# Temos 18207 linhas e 89 colunas

# %%
# obter nome das colunas
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
# variavel categorica
df.Nationality.unique()
# Out:
# array(['Argentina', 'Portugal', 'Brazil', 'Spain', 'Belgium', 'Croatia',
#        'Uruguay', 'Slovenia', 'Poland', 'Germany', 'France', 'England',
#        'Italy', 'Egypt', 'Colombia', 'Denmark', 'Gabon', 'Wales',
#        'Senegal', 'Costa Rica', 'Slovakia', 'Netherlands',
#        'Bosnia Herzegovina', 'Morocco', 'Serbia', 'Algeria', 'Austria',
#        'Greece', 'Chile', 'Sweden', 'Korea Republic', 'Finland', 'Guinea',
#        'Montenegro', 'Armenia', 'Switzerland', 'Norway', 'Czech Republic',
#        'Scotland', 'Ghana', 'Central African Rep.', 'DR Congo',
#        'Ivory Coast', 'Russia', 'Ukraine', 'Iceland', 'Mexico', 'Jamaica',
#        'Albania', 'Venezuela', 'Japan', 'Turkey', 'Ecuador', 'Paraguay',
#        'Mali', 'Nigeria', 'Cameroon', 'Dominican Republic', 'Israel',
#        'Kenya', 'Hungary', 'Republic of Ireland', 'Romania',
#        'United States', 'Cape Verde', 'Australia', 'Peru', 'Togo',
# ...

# %%
# quantos países têm no meu dataset?
len(df.Nationality.unique())
# Out:
# 164

# %%
# quantos clubes têm?
len(df.Club.unique())
# Out:
# 652

# %%
df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=18207, step=1)

# %% [markdown]
# Se quiser definir uma coluna como índice:
# - df.set_index('nome_da_coluna') # para uma coluna
# - df.set_index(['nome_da_coluna_1', 'nome_da_coluna_2',...]) # para varias colunas

# %%
display(df.head())
display(df.tail())
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
df
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
# como definir os parametros de exibicao?
pd.set_option("max_colwidth", 50)
pd.set_option("max_rows", 50)
pd.set_option("max_columns", 50)

df.head(50)
# Out:
#     Unnamed: 0      ID               Name  Age  \
# 0            0  158023           L. Messi   31
# 1            1   20801  Cristiano Ronaldo   33
# 2            2  190871          Neymar Jr   26
# 3            3  193080             De Gea   27
# 4            4  192985       K. De Bruyne   27
# 5            5  183277          E. Hazard   27
# 6            6  177003          L. Modrić   32
# 7            7  176580          L. Suárez   31
# 8            8  155862       Sergio Ramos   32
# 9            9  200389           J. Oblak   25
# 10          10  188545     R. Lewandowski   29
# 11          11  182521           T. Kroos   28
# 12          12  182493           D. Godín   32
# 13          13  168542        David Silva   32
# 14          14  215914           N. Kanté   27
# 15          15  211110          P. Dybala   24
# 16          16  202126            H. Kane   24
# 17          17  194765       A. Griezmann   27
# 18          18  192448      M. ter Stegen   26
# ...

# %%
pd.get_option('max_rows')
# Out:
# 50

# %%
# formatacao condicional
def color_negative_red(value):
    color = 'red' if value < 92 else 'black'
    return 'color: %s'%color # seria como se eu tivesse fazendo return 'color: red' ou return 'color: black'

df[['Overall', 'Potential']].head(10).style.applymap(color_negative_red)
# Out:
# <style  type="text/css" >
#     #T_3c5f79ec_0cb9_11eb_be5d_1c36bb156c46row0_col0 {
#             color:  black;
#         }    #T_3c5f79ec_0cb9_11eb_be5d_1c36bb156c46row0_col1 {
#             color:  black;
#         }    #T_3c5f79ec_0cb9_11eb_be5d_1c36bb156c46row1_col0 {
#             color:  black;
#         }    #T_3c5f79ec_0cb9_11eb_be5d_1c36bb156c46row1_col1 {
#             color:  black;
#         }    #T_3c5f79ec_0cb9_11eb_be5d_1c36bb156c46row2_col0 {
#             color:  black;
#         }    #T_3c5f79ec_0cb9_11eb_be5d_1c36bb156c46row2_col1 {
#             color:  black;
#         }    #T_3c5f79ec_0cb9_11eb_be5d_1c36bb156c46row3_col0 {
#             color:  red;
#         }    #T_3c5f79ec_0cb9_11eb_be5d_1c36bb156c46row3_col1 {
#             color:  black;
#         }    #T_3c5f79ec_0cb9_11eb_be5d_1c36bb156c46row4_col0 {
#             color:  red;
#         }    #T_3c5f79ec_0cb9_11eb_be5d_1c36bb156c46row4_col1 {
#             color:  black;
# ...

# %%
exemplo_df = df.head(10)
exemplo_df.style.applymap(color_negative_red, subset=['Overall', 'Potential'])
# Out:
# <style  type="text/css" >
#     #T_3c633942_0cb9_11eb_be5d_1c36bb156c46row0_col7 {
#             color:  black;
#         }    #T_3c633942_0cb9_11eb_be5d_1c36bb156c46row0_col8 {
#             color:  black;
#         }    #T_3c633942_0cb9_11eb_be5d_1c36bb156c46row1_col7 {
#             color:  black;
#         }    #T_3c633942_0cb9_11eb_be5d_1c36bb156c46row1_col8 {
#             color:  black;
#         }    #T_3c633942_0cb9_11eb_be5d_1c36bb156c46row2_col7 {
#             color:  black;
#         }    #T_3c633942_0cb9_11eb_be5d_1c36bb156c46row2_col8 {
#             color:  black;
#         }    #T_3c633942_0cb9_11eb_be5d_1c36bb156c46row3_col7 {
#             color:  red;
#         }    #T_3c633942_0cb9_11eb_be5d_1c36bb156c46row3_col8 {
#             color:  black;
#         }    #T_3c633942_0cb9_11eb_be5d_1c36bb156c46row4_col7 {
#             color:  red;
#         }    #T_3c633942_0cb9_11eb_be5d_1c36bb156c46row4_col8 {
#             color:  black;
# ...

# %%
# mudar cor de fundo para o valor maximo
def highlight_max(value):
    is_max = value == value.max() # value==value.max(), depois guardei em is_max
    return ['background-color: yellow' if v else '' for v in is_max]

df.head(10).style.apply(highlight_max, subset=['Age', 'Overall', 'Potential'])
# Out:
# <style  type="text/css" >
#     #T_3c6fc900_0cb9_11eb_be5d_1c36bb156c46row0_col7 {
#             background-color:  yellow;
#         }    #T_3c6fc900_0cb9_11eb_be5d_1c36bb156c46row0_col8 {
#             background-color:  yellow;
#         }    #T_3c6fc900_0cb9_11eb_be5d_1c36bb156c46row1_col3 {
#             background-color:  yellow;
#         }    #T_3c6fc900_0cb9_11eb_be5d_1c36bb156c46row1_col7 {
#             background-color:  yellow;
#         }    #T_3c6fc900_0cb9_11eb_be5d_1c36bb156c46row1_col8 {
#             background-color:  yellow;
# ...

# %%
def color_negative_red(value):
    color = 'red' if value < 30 else 'green'
    return 'color: %s'%color # seria como se eu tivesse fazendo return 'color: red' ou return 'color: black'

df[['Age']].head(10).style.applymap(color_negative_red).apply(highlight_max)
# Out:
# <style  type="text/css" >
#     #T_3c7be730_0cb9_11eb_be5d_1c36bb156c46row0_col0 {
#             color:  green;
#             : ;
#         }    #T_3c7be730_0cb9_11eb_be5d_1c36bb156c46row1_col0 {
#             color:  green;
#             background-color:  yellow;
#         }    #T_3c7be730_0cb9_11eb_be5d_1c36bb156c46row2_col0 {
#             color:  red;
#             : ;
#         }    #T_3c7be730_0cb9_11eb_be5d_1c36bb156c46row3_col0 {
#             color:  red;
#             : ;
#         }    #T_3c7be730_0cb9_11eb_be5d_1c36bb156c46row4_col0 {
#             color:  red;
#             : ;
#         }    #T_3c7be730_0cb9_11eb_be5d_1c36bb156c46row5_col0 {
#             color:  red;
#             : ;
#         }    #T_3c7be730_0cb9_11eb_be5d_1c36bb156c46row6_col0 {
#             color:  green;
#             : ;
#         }    #T_3c7be730_0cb9_11eb_be5d_1c36bb156c46row7_col0 {
#             color:  green;
#             : ;
# ...

# %% [markdown]
# Mais sobre formatações em: https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html

# %%
# Os mais populares: loc e iloc
df.loc[0:3] # da linha 0 a linha 3
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
#
#                   Club                                     Club Logo    Value  \
# ...

# %%
df.loc[0:3, 'ID']
# Out:
# 0    158023
# 1     20801
# 2    190871
# 3    193080
# Name: ID, dtype: int64

# %%
df.loc[0:3, ['ID','Nationality']]
# Out:
#        ID Nationality
# 0  158023   Argentina
# 1   20801    Portugal
# 2  190871      Brazil
# 3  193080       Spain

# %%
df.iloc[0:3, 5:8]
# Out:
#   Nationality                                 Flag  Overall
# 0   Argentina  https://cdn.sofifa.org/flags/52.png       94
# 1    Portugal  https://cdn.sofifa.org/flags/38.png       94
# 2      Brazil  https://cdn.sofifa.org/flags/54.png       92

# %%
df[df['Age'] > 30]
# Out:
#        Unnamed: 0      ID               Name  Age  \
# 0               0  158023           L. Messi   31
# 1               1   20801  Cristiano Ronaldo   33
# 6               6  177003          L. Modrić   32
# 7               7  176580          L. Suárez   31
# 8               8  155862       Sergio Ramos   32
# ...           ...     ...                ...  ...
# 17842       17842  182461          Zhou Ting   39
# 17866       17866  232676           N. Hatta   32
# 18043       18043  237917          A. Suzuki   31
# 18171       18171  237746        Y. Uchimura   33
# 18183       18183   53748      K. Pilkington   44
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 6      https://cdn.sofifa.org/players/4/19/177003.png     Croatia
# 7      https://cdn.sofifa.org/players/4/19/176580.png     Uruguay
# ...

# %%
df[df['Overall']>90]
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
# 5           5  183277          E. Hazard   27
# 6           6  177003          L. Modrić   32
# 7           7  176580          L. Suárez   31
# 8           8  155862       Sergio Ramos   32
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# 5  https://cdn.sofifa.org/players/4/19/183277.png     Belgium
# 6  https://cdn.sofifa.org/players/4/19/177003.png     Croatia
# ...

# %%
df.loc[(df['Age']>30) & (df['Overall']>=90)]
# Out:
#     Unnamed: 0      ID               Name  Age  \
# 0            0  158023           L. Messi   31
# 1            1   20801  Cristiano Ronaldo   33
# 6            6  177003          L. Modrić   32
# 7            7  176580          L. Suárez   31
# 8            8  155862       Sergio Ramos   32
# 12          12  182493           D. Godín   32
# 13          13  168542        David Silva   32
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1    https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 6   https://cdn.sofifa.org/players/4/19/177003.png     Croatia
# 7   https://cdn.sofifa.org/players/4/19/176580.png     Uruguay
# 8   https://cdn.sofifa.org/players/4/19/155862.png       Spain
# 12  https://cdn.sofifa.org/players/4/19/182493.png     Uruguay
# 13  https://cdn.sofifa.org/players/4/19/168542.png       Spain
#
# ...

# %%
df.query("Age > 30 & Overall >= 90")
# Out:
#     Unnamed: 0      ID               Name  Age  \
# 0            0  158023           L. Messi   31
# 1            1   20801  Cristiano Ronaldo   33
# 6            6  177003          L. Modrić   32
# 7            7  176580          L. Suárez   31
# 8            8  155862       Sergio Ramos   32
# 12          12  182493           D. Godín   32
# 13          13  168542        David Silva   32
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1    https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 6   https://cdn.sofifa.org/players/4/19/177003.png     Croatia
# 7   https://cdn.sofifa.org/players/4/19/176580.png     Uruguay
# 8   https://cdn.sofifa.org/players/4/19/155862.png       Spain
# 12  https://cdn.sofifa.org/players/4/19/182493.png     Uruguay
# 13  https://cdn.sofifa.org/players/4/19/168542.png       Spain
#
# ...

# %%
df[df['GKDiving']==df['GKHandling']]
# Out:
#        Unnamed: 0      ID          Name  Age  \
# 2               2  190871     Neymar Jr   26
# 24             24  138956  G. Chiellini   33
# 26             26  209331      M. Salah   26
# 28             28  198710  J. Rodríguez   26
# 36             36  173731       G. Bale   28
# ...           ...     ...           ...  ...
# 18153       18153  246270    M. Dyrmose   17
# 18156       18156  245533     J. Devine   18
# 18192       18192  245571     S. Squire   18
# 18194       18194  245862      J. Milli   18
# 18199       18199  244677  M. Baldisimo   18
#
#                                                 Photo Nationality  \
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 24     https://cdn.sofifa.org/players/4/19/138956.png       Italy
# 26     https://cdn.sofifa.org/players/4/19/209331.png       Egypt
# 28     https://cdn.sofifa.org/players/4/19/198710.png    Colombia
# 36     https://cdn.sofifa.org/players/4/19/173731.png       Wales
# ...

# %%
df_exemplo = df.filter(['ID','Age','Name'])
df_exemplo.head()
# Out:
#        ID  Age               Name
# 0  158023   31           L. Messi
# 1   20801   33  Cristiano Ronaldo
# 2  190871   26          Neymar Jr
# 3  193080   27             De Gea
# 4  192985   27       K. De Bruyne

# %%
df_copy = df.copy()

# %%
overall_mediana = df['Overall'].median()
df.query("Overall > @overall_mediana")
# Out:
#       Unnamed: 0      ID               Name  Age  \
# 0              0  158023           L. Messi   31
# 1              1   20801  Cristiano Ronaldo   33
# 2              2  190871          Neymar Jr   26
# 3              3  193080             De Gea   27
# 4              4  192985       K. De Bruyne   27
# ...          ...     ...                ...  ...
# 8759        8759  224509           U. Rivas   22
# 8760        8760  214014        C. Lizarazo   27
# 8761        8761  104702         D. Braaten   36
# 8762        8762  229631               Lazo   22
# 8763        8763  246015            L. Mago   23
#
#                                                Photo Nationality  \
# 0     https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1      https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2     https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3     https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
overall_mediana
# Out:
# 66.0

# %%
df_BR = df.query("Nationality=='Brazil'")
df_BR.head()
# Out:
#     Unnamed: 0      ID          Name  Age  \
# 2            2  190871     Neymar Jr   26
# 27          27  200145      Casemiro   26
# 32          32  189242      Coutinho   26
# 35          35  176676       Marcelo   30
# 39          39  164240  Thiago Silva   33
#
#                                              Photo Nationality  \
# 2   https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 27  https://cdn.sofifa.org/players/4/19/200145.png      Brazil
# 32  https://cdn.sofifa.org/players/4/19/189242.png      Brazil
# 35  https://cdn.sofifa.org/players/4/19/176676.png      Brazil
# 39  https://cdn.sofifa.org/players/4/19/164240.png      Brazil
#
#                                    Flag  Overall  Potential  \
# 2   https://cdn.sofifa.org/flags/54.png       92         93
# 27  https://cdn.sofifa.org/flags/54.png       88         90
# 32  https://cdn.sofifa.org/flags/54.png       88         89
# 35  https://cdn.sofifa.org/flags/54.png       88         88
# ...

# %%
df_champ= df[df['Nationality'].isin(['Argentina','Brazil', 'Germany', 'France'])]

df_champ.head()
# Out:
#     Unnamed: 0      ID       Name  Age  \
# 0            0  158023   L. Messi   31
# 2            2  190871  Neymar Jr   26
# 11          11  182521   T. Kroos   28
# 14          14  215914   N. Kanté   27
# 15          15  211110  P. Dybala   24
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 2   https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 11  https://cdn.sofifa.org/players/4/19/182521.png     Germany
# 14  https://cdn.sofifa.org/players/4/19/215914.png      France
# 15  https://cdn.sofifa.org/players/4/19/211110.png   Argentina
#
#                                    Flag  Overall  Potential  \
# 0   https://cdn.sofifa.org/flags/52.png       94         94
# 2   https://cdn.sofifa.org/flags/54.png       92         93
# 11  https://cdn.sofifa.org/flags/21.png       90         90
# 14  https://cdn.sofifa.org/flags/18.png       89         90
# ...

# %%
df_non_champ= df[~df['Nationality'].isin(['Argentina','Brazil', 'Germany', 'France'])]

df_non_champ.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 1           1   20801  Cristiano Ronaldo   33
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
# 5           5  183277          E. Hazard   27
# 6           6  177003          L. Modrić   32
#
#                                             Photo Nationality  \
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# 5  https://cdn.sofifa.org/players/4/19/183277.png     Belgium
# 6  https://cdn.sofifa.org/players/4/19/177003.png     Croatia
#
#                                   Flag  Overall  Potential               Club  \
# 1  https://cdn.sofifa.org/flags/38.png       94         94           Juventus
# 3  https://cdn.sofifa.org/flags/45.png       91         93  Manchester United
# ...

# %%
# filtrar somente campos numericos
numerics = ['int16','int32','int64','float16','float32','float64']
df_numeric = df.select_dtypes(include=numerics)
df_numeric
# Out:
#        Unnamed: 0      ID  Age  Overall  Potential  Special  \
# 0               0  158023   31       94         94     2202
# 1               1   20801   33       94         94     2228
# 2               2  190871   26       92         93     2143
# 3               3  193080   27       91         93     1471
# 4               4  192985   27       91         92     2281
# ...           ...     ...  ...      ...        ...      ...
# 18202       18202  238813   19       47         65     1307
# 18203       18203  243165   19       47         63     1098
# 18204       18204  241638   16       47         67     1189
# 18205       18205  246268   17       47         66     1228
# 18206       18206  246269   16       46         66     1321
#
#        International Reputation  Weak Foot  Skill Moves  Jersey Number  \
# 0                           5.0        4.0          4.0           10.0
# 1                           5.0        4.0          5.0            7.0
# ...

# %%
df.sort_values(by='Overall', ascending=False)
# Out:
#        Unnamed: 0      ID               Name  Age  \
# 0               0  158023           L. Messi   31
# 1               1   20801  Cristiano Ronaldo   33
# 2               2  190871          Neymar Jr   26
# 3               3  193080             De Gea   27
# 4               4  192985       K. De Bruyne   27
# ...           ...     ...                ...  ...
# 18190       18190  245569         L. Watkins   18
# 18189       18189  240160         A. Kaltner   18
# 18187       18187  240158          C. Ehlich   19
# 18186       18186  240917       Zhang Yufeng   20
# 18206       18206  246269          G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
df.drop_duplicates()
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
# Estatistica descritiva
df.describe()
# Out:
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  18207.000000   18207.000000  18207.000000  18207.000000  18207.000000
# mean    9103.000000  214298.338606     25.122206     66.238699     71.307299
# std     5256.052511   29965.244204      4.669943      6.908930      6.136496
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     4551.500000  200315.500000     21.000000     62.000000     67.000000
# 50%     9103.000000  221759.000000     25.000000     66.000000     71.000000
# 75%    13654.500000  236529.500000     28.000000     71.000000     75.000000
# max    18206.000000  246620.000000     45.000000     94.000000     95.000000
#
#             Special  International Reputation     Weak Foot   Skill Moves  \
# count  18207.000000              18159.000000  18159.000000  18159.000000
# mean    1597.809908                  1.113222      2.947299      2.361308
# ...

# %%
df['Age'].describe(percentiles=[0.1, 0.2, 0.95, 0.99])
# Out:
# count    18207.000000
# mean        25.122206
# std          4.669943
# min         16.000000
# 10%         19.000000
# 20%         21.000000
# 50%         25.000000
# 95%         33.000000
# 99%         36.000000
# max         45.000000
# Name: Age, dtype: float64

# %%
df.agg({'Age':['min','max'],
        'Overall':['median', 'skew'],
        'Special':['mean']})
# Out:
#          Age    Overall      Special
# max     45.0        NaN          NaN
# mean     NaN        NaN  1597.809908
# median   NaN  66.000000          NaN
# min     16.0        NaN          NaN
# skew     NaN   0.067185          NaN

# %%
df_champ.head()
# Out:
#     Unnamed: 0      ID       Name  Age  \
# 0            0  158023   L. Messi   31
# 2            2  190871  Neymar Jr   26
# 11          11  182521   T. Kroos   28
# 14          14  215914   N. Kanté   27
# 15          15  211110  P. Dybala   24
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 2   https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 11  https://cdn.sofifa.org/players/4/19/182521.png     Germany
# 14  https://cdn.sofifa.org/players/4/19/215914.png      France
# 15  https://cdn.sofifa.org/players/4/19/211110.png   Argentina
#
#                                    Flag  Overall  Potential  \
# 0   https://cdn.sofifa.org/flags/52.png       94         94
# 2   https://cdn.sofifa.org/flags/54.png       92         93
# 11  https://cdn.sofifa.org/flags/21.png       90         90
# 14  https://cdn.sofifa.org/flags/18.png       89         90
# ...

# %%
df_champ.groupby("Nationality")['Overall'].mean()
# Out:
# Nationality
# Argentina    68.572038
# Brazil       71.251511
# France       67.798687
# Germany      66.086811
# Name: Overall, dtype: float64

# %%
df_champ.groupby(["Nationality","Club"])['Overall','Age'].mean()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                                 Overall    Age
# Nationality Club
# Argentina   AD Alcorcón            68.0  26.00
#             AEK Athens             72.0  21.50
#             AIK                    67.0  24.00
#             AJ Auxerre             68.0  21.00
#             Ajax                   80.0  25.00
# ...                                 ...    ...
# Germany     Wisła Płock            63.0  24.00
#             Wolfsberger AC         69.0  29.00
#             Yeni Malatyaspor       72.0  28.00
#             Zagłębie Sosnowiec     64.0  26.00
#             Çaykur Rizespor        67.0  26.75
#
# [748 rows x 2 columns]

# %%
import numpy as np

pd.pivot_table(df_champ, index='Nationality', aggfunc = np.mean)
# Out:
#              Acceleration        Age  Aggression    Agility    Balance  \
# Nationality
# Argentina       64.625000  26.205977   56.725427  64.193376  64.376068
# Brazil          66.318788  27.625151   59.972121  65.201212  63.966061
# France          64.524698  24.615974   56.958288  62.819978  63.919868
# Germany         63.287029  24.338063   55.931381  62.354812  61.830126
#
#              BallControl  Composure   Crossing      Curve  Dribbling  \
# Nationality
# Argentina      60.808761  60.452991  51.319444  48.883547  58.068376
# Brazil         63.841212  65.241212  54.699394  53.403636  60.850909
# France         59.787047  60.586169  51.739846  47.963776  56.736553
# Germany        56.675314  56.370711  48.337238  45.133054  53.167364
#
#              FKAccuracy  Finishing   GKDiving  GKHandling  GKKicking  \
# Nationality
# Argentina     44.883547  48.126068  16.309829   16.286325  16.285256
# Brazil        50.255758  50.659394  15.846061   15.440000  15.509091
# ...

# %%
pd.pivot_table(df_champ, index=['Nationality','Club'], values=['Age','Overall','Potential'], aggfunc=np.mean)
# Out:
#                                   Age  Overall  Potential
# Nationality Club
# Argentina   AD Alcorcón         26.00     68.0       72.0
#             AEK Athens          21.50     72.0       80.5
#             AIK                 24.00     67.0       74.0
#             AJ Auxerre          21.00     68.0       79.0
#             Ajax                25.00     80.0       82.0
# ...                               ...      ...        ...
# Germany     Wisła Płock         24.00     63.0       68.0
#             Wolfsberger AC      29.00     69.0       69.0
#             Yeni Malatyaspor    28.00     72.0       72.0
#             Zagłębie Sosnowiec  26.00     64.0       66.0
#             Çaykur Rizespor     26.75     67.0       72.5
#
# [748 rows x 3 columns]

# %%
pd.pivot_table(df_champ, index=['Nationality'], columns=['Position'],values=['Age','Overall','Potential'], aggfunc=np.mean)
# Out:
#                    Age                                                    \
# Position           CAM         CB        CDM    CF         CM         GK
# Nationality
# Argentina    27.391304  26.050505  25.763636  23.5  23.500000  28.195876
# Brazil       28.074074  27.742424  27.813953  26.5  24.277778  28.911765
# France       25.156863  23.741935  23.603175   NaN  23.120690  24.891089
# Germany      22.822581  24.250000  24.367089  22.0  22.916667  24.487805
#
#                                                                                \
# Position           LAM         LB        LCB        LCM        LDM         LF
# Nationality
# Argentina          NaN  25.728814  28.314286  26.200000  30.000000  26.666667
# Brazil       30.923077  27.626866  28.468085  27.312500  28.880000  24.000000
# France             NaN  24.641026  26.648649  26.000000  25.941176        NaN
# Germany      25.000000  24.012658  25.846154  25.882353  25.304348  31.000000
#
# ...

# %%
df.Nationality.unique()
# Out:
# array(['Argentina', 'Portugal', 'Brazil', 'Spain', 'Belgium', 'Croatia',
#        'Uruguay', 'Slovenia', 'Poland', 'Germany', 'France', 'England',
#        'Italy', 'Egypt', 'Colombia', 'Denmark', 'Gabon', 'Wales',
#        'Senegal', 'Costa Rica', 'Slovakia', 'Netherlands',
#        'Bosnia Herzegovina', 'Morocco', 'Serbia', 'Algeria', 'Austria',
#        'Greece', 'Chile', 'Sweden', 'Korea Republic', 'Finland', 'Guinea',
#        'Montenegro', 'Armenia', 'Switzerland', 'Norway', 'Czech Republic',
#        'Scotland', 'Ghana', 'Central African Rep.', 'DR Congo',
#        'Ivory Coast', 'Russia', 'Ukraine', 'Iceland', 'Mexico', 'Jamaica',
#        'Albania', 'Venezuela', 'Japan', 'Turkey', 'Ecuador', 'Paraguay',
#        'Mali', 'Nigeria', 'Cameroon', 'Dominican Republic', 'Israel',
#        'Kenya', 'Hungary', 'Republic of Ireland', 'Romania',
#        'United States', 'Cape Verde', 'Australia', 'Peru', 'Togo',
# ...

# %%
df_champ.Nationality.unique()
# Out:
# array(['Argentina', 'Brazil', 'Germany', 'France'], dtype=object)

# %%
df_champ.Nationality.value_counts()
# Out:
# Germany      1198
# Argentina     937
# France        914
# Brazil        827
# Name: Nationality, dtype: int64

# %%
df_champ.Nationality.value_counts(normalize=True)
# Out:
# Germany      0.309082
# Argentina    0.241744
# France       0.235810
# Brazil       0.213364
# Name: Nationality, dtype: float64

# %%
df_champ.groupby('Club')['Nationality'].value_counts()
# Out:
# Club                   Nationality
#  SSV Jahn Regensburg   Germany        22
# 1. FC Heidenheim 1846  Germany        27
# 1. FC Kaiserslautern   Germany        21
# 1. FC Köln             Germany        20
#                        France          2
#                                       ..
# Zagłębie Sosnowiec     Germany         1
# Çaykur Rizespor        Germany         4
#                        Brazil          1
#                        France          1
# Örebro SK              Brazil          1
# Name: Nationality, Length: 748, dtype: int64

# %%
df[df['Nationality'].map(df['Nationality'].value_counts()>1000)]
# Out:
#        Unnamed: 0      ID            Name  Age  \
# 3               3  193080          De Gea   27
# 8               8  155862    Sergio Ramos   32
# 11             11  182521        T. Kroos   28
# 13             13  168542     David Silva   32
# 16             16  202126         H. Kane   24
# ...           ...     ...             ...  ...
# 18198       18198  242844      J. Livesey   18
# 18202       18202  238813    J. Lundstram   19
# 18204       18204  241638       B. Worman   16
# 18205       18205  246268  D. Walker-Rice   17
# 18206       18206  246269       G. Nugent   16
#
#                                                 Photo Nationality  \
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 8      https://cdn.sofifa.org/players/4/19/155862.png       Spain
# 11     https://cdn.sofifa.org/players/4/19/182521.png     Germany
# 13     https://cdn.sofifa.org/players/4/19/168542.png       Spain
# ...

# %%
# COMO USAR SQL NO PYTHON?
import pandasql as ps

# %%
query = """
select ID, Age, Name
from df 
where Age > 30 and Overall >= 90
"""

velhos_craques = ps.sqldf(query, locals())
velhos_craques.head()
# Out:
#        ID  Age               Name
# 0  158023   31           L. Messi
# 1   20801   33  Cristiano Ronaldo
# 2  177003   32          L. Modrić
# 3  176580   31          L. Suárez
# 4  155862   32       Sergio Ramos

# %% [markdown]
# ## Missing e Alterações/Criações de Campos

# %%
df_null = df[['ID','Name', 'LCB', 'LB']].head(10)
df_null
# Out:
#        ID               Name   LCB    LB
# 0  158023           L. Messi  47+2  59+2
# 1   20801  Cristiano Ronaldo  53+3  61+3
# 2  190871          Neymar Jr  47+3  60+3
# 3  193080             De Gea   NaN   NaN
# 4  192985       K. De Bruyne  66+3  73+3
# 5  183277          E. Hazard  49+3  60+3
# 6  177003          L. Modrić  71+3  79+3
# 7  176580          L. Suárez  63+5  66+5
# 8  155862       Sergio Ramos  87+3  84+3
# 9  200389           J. Oblak   NaN   NaN

# %%
df_null.isna()
# Out:
#       ID   Name    LCB     LB
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False   True   True
# 4  False  False  False  False
# 5  False  False  False  False
# 6  False  False  False  False
# 7  False  False  False  False
# 8  False  False  False  False
# 9  False  False   True   True

# %%
df_null.isna().sum()
# Out:
# ID      0
# Name    0
# LCB     2
# LB      2
# dtype: int64

# %%
df_null.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      10 non-null     int64
#  1   Name    10 non-null     object
#  2   LCB     8 non-null      object
#  3   LB      8 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 400.0+ bytes

# %%
df_null[pd.isna(df_null['LCB'])] #filtrar linhas com campo LCB missing
# Out:
#        ID      Name  LCB   LB
# 3  193080    De Gea  NaN  NaN
# 9  200389  J. Oblak  NaN  NaN

# %%
df_null[df_null['LCB'].notna()] # filtra quem nao tem LCB missing
# Out:
#        ID               Name   LCB    LB
# 0  158023           L. Messi  47+2  59+2
# 1   20801  Cristiano Ronaldo  53+3  61+3
# 2  190871          Neymar Jr  47+3  60+3
# 4  192985       K. De Bruyne  66+3  73+3
# 5  183277          E. Hazard  49+3  60+3
# 6  177003          L. Modrić  71+3  79+3
# 7  176580          L. Suárez  63+5  66+5
# 8  155862       Sergio Ramos  87+3  84+3

# %%
df_null.fillna('0')
# Out:
#        ID               Name   LCB    LB
# 0  158023           L. Messi  47+2  59+2
# 1   20801  Cristiano Ronaldo  53+3  61+3
# 2  190871          Neymar Jr  47+3  60+3
# 3  193080             De Gea     0     0
# 4  192985       K. De Bruyne  66+3  73+3
# 5  183277          E. Hazard  49+3  60+3
# 6  177003          L. Modrić  71+3  79+3
# 7  176580          L. Suárez  63+5  66+5
# 8  155862       Sergio Ramos  87+3  84+3
# 9  200389           J. Oblak     0     0

# %%
df_null
# Out:
#        ID               Name   LCB    LB
# 0  158023           L. Messi  47+2  59+2
# 1   20801  Cristiano Ronaldo  53+3  61+3
# 2  190871          Neymar Jr  47+3  60+3
# 3  193080             De Gea   NaN   NaN
# 4  192985       K. De Bruyne  66+3  73+3
# 5  183277          E. Hazard  49+3  60+3
# 6  177003          L. Modrić  71+3  79+3
# 7  176580          L. Suárez  63+5  66+5
# 8  155862       Sergio Ramos  87+3  84+3
# 9  200389           J. Oblak   NaN   NaN

# %%
# Se estivesse numerico, preencher com media:
# df_null.fillna(df_null.mean(), inplace=True)
# Out:
#        ID               Name   LCB    LB
# 0  158023           L. Messi  47+2  59+2
# 1   20801  Cristiano Ronaldo  53+3  61+3
# 2  190871          Neymar Jr  47+3  60+3
# 3  193080             De Gea   NaN   NaN
# 4  192985       K. De Bruyne  66+3  73+3
# 5  183277          E. Hazard  49+3  60+3
# 6  177003          L. Modrić  71+3  79+3
# 7  176580          L. Suárez  63+5  66+5
# 8  155862       Sergio Ramos  87+3  84+3
# 9  200389           J. Oblak   NaN   NaN

# %%
values = {'LCB': '0', 'LB': '999999'}
df_null.fillna(value = values)
# Out:
#        ID               Name   LCB      LB
# 0  158023           L. Messi  47+2    59+2
# 1   20801  Cristiano Ronaldo  53+3    61+3
# 2  190871          Neymar Jr  47+3    60+3
# 3  193080             De Gea     0  999999
# 4  192985       K. De Bruyne  66+3    73+3
# 5  183277          E. Hazard  49+3    60+3
# 6  177003          L. Modrić  71+3    79+3
# 7  176580          L. Suárez  63+5    66+5
# 8  155862       Sergio Ramos  87+3    84+3
# 9  200389           J. Oblak     0  999999

# %%
df_null.dropna()
# Out:
#        ID               Name   LCB    LB
# 0  158023           L. Messi  47+2  59+2
# 1   20801  Cristiano Ronaldo  53+3  61+3
# 2  190871          Neymar Jr  47+3  60+3
# 4  192985       K. De Bruyne  66+3  73+3
# 5  183277          E. Hazard  49+3  60+3
# 6  177003          L. Modrić  71+3  79+3
# 7  176580          L. Suárez  63+5  66+5
# 8  155862       Sergio Ramos  87+3  84+3

# %%
df_null.dropna(subset=['LCB']) # exclui missing somente de quem está no subset
# Out:
#        ID               Name   LCB    LB
# 0  158023           L. Messi  47+2  59+2
# 1   20801  Cristiano Ronaldo  53+3  61+3
# 2  190871          Neymar Jr  47+3  60+3
# 4  192985       K. De Bruyne  66+3  73+3
# 5  183277          E. Hazard  49+3  60+3
# 6  177003          L. Modrić  71+3  79+3
# 7  176580          L. Suárez  63+5  66+5
# 8  155862       Sergio Ramos  87+3  84+3

# %%
df['Weight'].head()
# Out:
# 0    159lbs
# 1    183lbs
# 2    150lbs
# 3    168lbs
# 4    154lbs
# Name: Weight, dtype: object

# %%
df['Weight'].fillna('0lbs', inplace=True)

# %%
teste = df['Weight'].head()
teste[1].replace('lbs','')
# Out:
# '183'

# %%
def substitui_lbs(value):
    """funcao para tratar campo peso """
    x = value.replace('lbs', '')
    return int(x)

df['Weight_New'] = df['Weight'].apply(substitui_lbs)
df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
df[['Weight_New']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18207 entries, 0 to 18206
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Weight_New  18207 non-null  int64
# dtypes: int64(1)
# memory usage: 284.5 KB

# %%
# Convertendo campo salario
def converte_wage(value):
    value_2 = value.replace('€','')
    if 'M' in value_2:
        value_2 = value_2.replace('M','')
        return float(value_2)*1000000
    elif 'K' in value_2:
        value_2 = value_2.replace('K','')
        return float(value_2)*1000

df['Wage_Numeric'] = df['Wage'].apply(converte_wage)
df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
df['avg_GK'] = (df['GKDiving']+df['GKHandling']+df['GKKicking']+df['GKPositioning']+df['GKReflexes'])/5
df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
# Cria um campo condicional a outro
df['Age_Class'] = np.where(df['Age']>30, 'Old', 'Young') # import numpy as np
df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
df['Age_Class2'] = 'Young'
df.loc[df['Age']>30, 'Age_Class2'] = 'Old'
df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %% [markdown]
# ## Extras

# %%
# Criar dataframe a partir de clipboard. Simplesmente copie a tabele faça:
df_clipboard = pd.read_clipboard()

# %%
# usar dados dummies pra treinar modelos
pd.util.testing.makeDataFrame()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/util/__init__.py:12: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing
#                    A         B         C         D
# mc7ZS0cUUw -0.075890 -0.057144  2.157236  1.255489
# yDkO9ahOoY  0.320852 -0.999713 -0.274341  1.839252
# PIDQYxPEZR -0.553774 -1.282639 -1.563118  1.554215
# hfZ4bm3RzH -0.073528 -2.447612  0.259487  0.280751
# q6whIxC2xb -0.452558 -0.650944 -0.475911 -0.816292
# YTgrhgKdHi -0.218845 -2.085078  1.286149  0.659886
# 3uJJselTzH  0.693229  0.722467 -1.766048 -0.671229
# I0EjvZbINF -0.547403  0.293843 -0.465116  0.816699
# hLrwemjlfH  0.702010  2.078355  0.267719  1.533597
# JRbsLAJngZ  0.227003  0.923012  0.468947 -0.804477
# cVl9PWOBDg  1.076169  0.550741 -0.874462 -1.426532
# KOTe3Kos5l  0.217617 -0.305646 -0.343807  1.214526
# dzG1Y9SCle -1.227581  0.563496  0.125203  0.251420
# ...

# %%
# ler csv
# df = pd.read_csv()

# exportar para csv
df.to_csv('fifa19_example.csv', sep=';', decimal=',')
